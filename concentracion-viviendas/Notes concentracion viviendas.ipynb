# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('grandes-tenedores-andalucia.csv')

# %%
df
# Out:
#            NIF                         Filial propietaria directa  Inmuebles  \
# 0    A11208899  EMPRESA PROVINCIAL DE VIVIENDA Y SUELO DE CADI...         50
# 1    B87588885                              AEDAS HOMES OPCO, SLU         50
# 2    B29365673                                 TORREMOLINOS 88 SL         50
# 3    B29142643                                          TRAISA SL         50
# 4    B04879086                              JAEN PLAZA PROJECT SL         51
# ..         ...                                                ...        ...
# 186  A93139053                                   UNICAJA BANCO SA       1566
# 187  A41047267  EMPRESA MUNICIPAL DE VIVIENDA, SUELO Y EQUIPAM...       2466
# 188  S4111001F                                 JUNTA DE ANDALUCIA       4264
# 189  A63106157                                 BUILDINGCENTER SAU       5846
# 190  Q9155006A  AGENCIA DE VIVIENDA Y REHABILITACION DE ANDALUCIA      13716
#
# ...

# %%
df.columns
# Out:
# Index(['NIF', 'Filial propietaria directa', 'Inmuebles', 'Fianzas depositadas',
#        'Matriz', 'Sede empresa matriz', 'Sociedad intermedia utilizada',
#        'Sede sociedad utilizada', 'Tipo sociedad utilizada', 'Administración',
#        'Sector', 'Subsector', 'Fuente', 'Fuente 2', 'Fuente 3', 'Fuente 4',
#        'Fuente 5', 'Fuente 6', 'Fuente 7', 'Fuente 8'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 191 entries, 0 to 190
# Data columns (total 20 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   NIF                            191 non-null    object
#  1   Filial propietaria directa     191 non-null    object
#  2   Inmuebles                      191 non-null    int64
#  3   Fianzas depositadas            191 non-null    object
#  4   Matriz                         191 non-null    object
#  5   Sede empresa matriz            191 non-null    object
#  6   Sociedad intermedia utilizada  191 non-null    object
#  7   Sede sociedad utilizada        191 non-null    object
#  8   Tipo sociedad utilizada        191 non-null    object
#  9   Administración                 43 non-null     object
#  10  Sector                         191 non-null    object
#  11  Subsector                      51 non-null     object
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of            NIF                         Filial propietaria directa  Inmuebles  \
# 0    A11208899  EMPRESA PROVINCIAL DE VIVIENDA Y SUELO DE CADI...         50
# 1    B87588885                              AEDAS HOMES OPCO, SLU         50
# 2    B29365673                                 TORREMOLINOS 88 SL         50
# 3    B29142643                                          TRAISA SL         50
# 4    B04879086                              JAEN PLAZA PROJECT SL         51
# ..         ...                                                ...        ...
# 186  A93139053                                   UNICAJA BANCO SA       1566
# 187  A41047267  EMPRESA MUNICIPAL DE VIVIENDA, SUELO Y EQUIPAM...       2466
# 188  S4111001F                                 JUNTA DE ANDALUCIA       4264
# 189  A63106157                                 BUILDINGCENTER SAU       5846
# 190  Q9155006A  AGENCIA DE VIVIENDA Y REHABILITACION DE ANDALUCIA      13716
#
# ...
